# %% [markdown]
# <a href="https://colab.research.google.com/github/RIOSMPW/OpenXRAM/blob/main/RIOSMPW/OpenXRAM/tree/main/ipdesignguide/digital-inverter-openlane-gf180mcu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Digital inverter with OpenLane
#
# ```
# Copyright 2022 Google LLC.
# SPDX-License-Identifier: Apache-2.0
# ```
#
# Run a simple digital inverter design thru the [OpenLane](https://github.com/The-OpenROAD-Project/OpenLane/) GDS to RTL flow targeting the [open source GF180MCU PDK](https://github.com/google/gf180mcu-pdk/).

# %%
#@title Install dependencies {display-mode: "form"}
#@markdown - Click the ▷ button to setup the digital design environment based on [conda-eda](https://github.com/hdl/conda-eda).

openlane_version = 'latest' #@param {type:"string"}
open_pdks_rev = '120b0bd69c745825a0b8b76f364043a1cd08bb6a' #@param {type:"string"}

if openlane_version == 'latest':
  openlane_version = ''

import os
import pathlib

# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xj bin/micromamba
conda_prefix_path = pathlib.Path('conda-env')
CONDA_PREFIX = str(conda_prefix_path.resolve())
# !bin/micromamba create --yes --prefix $CONDA_PREFIX
# !echo 'python ==3.7*' >> {CONDA_PREFIX}/conda-meta/pinned
# !CI=0 bin/micromamba install --quiet --yes --prefix $CONDA_PREFIX \
                     --channel litex-hub \
                     --channel main \
                     openlane={openlane_version}
# !python -m pip install gdstk tqdm
# install pdk manually: https://github.com/hdl/conda-eda/pull/238
pdk_root_path = conda_prefix_path / 'share/pdk'
pdk_root_path.mkdir(parents=True, exist_ok=True)
PDK_ROOT=str(pdk_root_path.resolve())
# %env PDK_ROOT={PDK_ROOT}
# !curl -L -O https://github.com/efabless/volare/releases/download/gf180mcu-{open_pdks_rev}/default.tar.xz
# !xz --decompress --stdout default.tar.xz | tqdm --bytes --total=`xz --robot --list default.tar.xz | sed -n 2p | cut -f5` > default.tar
# !tar -xvf default.tar -C {PDK_ROOT} gf180mcuC/ | tqdm --total=`tar -tf default.tar gf180mcuC/ | wc -l ` --null
PATH = os.environ['PATH']
# %env CONDA_PREFIX={CONDA_PREFIX}
# %env PATH={CONDA_PREFIX}/bin:{PATH}

# %% [markdown]
# ## Write verilog

# %%
# %%writefile inverter.v
# module inverter(input wire in, output wire out);
#     assign out = !in;
# endmodule
# Out:
# Writing inverter.v

# %% [markdown]
# ## Write configuration
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/configuration.html)

# %%
# %%writefile config.json
# {
#     "DESIGN_NAME": "inverter",
#     "VERILOG_FILES": "dir::inverter.v",
#     "CLOCK_PORT": null,
#     "PL_RANDOM_GLB_PLACEMENT": true,
#     "FP_SIZING": "absolute",
#     "DIE_AREA": "0 0 34.5 57.12",
#     "PL_TARGET_DENSITY": 0.75,
#     "FP_PDN_AUTO_ADJUST": false,
#     "FP_PDN_VPITCH": 25,
#     "FP_PDN_HPITCH": 25,
#     "FP_PDN_VOFFSET": 5,
#     "FP_PDN_HOFFSET": 5,
#     "DIODE_INSERTION_STRATEGY": 3
# }
# Out:
# Overwriting config.json

# %% [markdown]
# ## Run OpenLane Flow
# [OpenLane](https://openlane.readthedocs.io/en/latest/) is an automated [RTL](https://en.wikipedia.org/wiki/Register-transfer_level) to [GDSII](https://en.wikipedia.org/wiki/GDSII) flow based on several components including [OpenROAD](https://theopenroadproject.org/), [Yosys](https://yosyshq.net/yosys/), [Magic](http://www.opencircuitdesign.com/magic/), [Netgen](http://opencircuitdesign.com/netgen/) and custom methodology scripts for design exploration and optimization targeting [open source PDKs](https://github.com/google/open-source-pdks).
#
# ![img](https://openlane.readthedocs.io/en/latest/_images/flow_v1.png)

# %%
# %env PDK=gf180mcuC
# !flow.tcl -design .
# Out:
# env: PDK=gf180mcuC
# OpenLane 2023.06.26_0_g3bc9d02d-conda
# All rights reserved. (c) 2020-2022 Efabless Corporation and contributors.
# Available under the Apache License, version 2.0. See the LICENSE file for more details.
#
# [INFO]: Using configuration in 'config.json'...
# [INFO]: PDK Root: /content/conda-env/share/pdk
# [INFO]: Process Design Kit: gf180mcuC
# [INFO]: Standard Cell Library: gf180mcu_fd_sc_mcu7t5v0
# [INFO]: Optimization Standard Cell Library: gf180mcu_fd_sc_mcu7t5v0
# [WARNING]: FP_PDN_RAILS_LAYER is now deprecated; use FP_PDN_RAIL_LAYER instead.
# [WARNING]: FP_PDN_UPPER_LAYER is now deprecated; use FP_PDN_HORIZONTAL_LAYER instead.
# [WARNING]: FP_PDN_LOWER_LAYER is now deprecated; use FP_PDN_VERTICAL_LAYER instead.
# [WARNING]: DIODE_INSERTION_STRATEGY is now deprecated; use GRT_REPAIR_ANTENNAS, DIODE_ON_PORTS and RUN_HEURISTIC_DIODE_INSERTION instead.
# [INFO]: DIODE_INSERTION_STRATEGY set to 3. Setting GRT_REPAIR_ANTENNAS to 1
# [INFO]: Run Directory: /content/runs/RUN_2023.07.03_06.39.20
# [INFO]: Saving runtime environment...
# [INFO]: Preparing LEF files for the nom corner...
# [WARNING]: PDK 'gf180mcuC', SCL 'gf180mcu_fd_sc_mcu7t5v0' will generate errors with instantiated stdcells in the design.
# [WARNING]: Either disable QUIT_ON_LINTER_ERRORS or remove the instantiated cells.
# [INFO]: Running linter (Verilator) (log: runs/RUN_2023.07.03_06.39.20/logs/synthesis/linter.log)...
# [INFO]: 0 errors found by linter
# [INFO]: 0 warnings found by linter
# [STEP 1]
# [INFO]: Running Synthesis (log: runs/RUN_2023.07.03_06.39.20/logs/synthesis/1-synthesis.log)...
# [STEP 2]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.07.03_06.39.20/logs/synthesis/2-sta.log)...
# [STEP 3]
# [INFO]: Running Initial Floorplanning (log: runs/RUN_2023.07.03_06.39.20/logs/floorplan/3-initial_fp.log)...
# [INFO]: Floorplanned with width 20.72 and height 23.52.
# [STEP 4]
# [INFO]: Running IO Placement...
# [STEP 5]
# [INFO]: Running Tap/Decap Insertion (log: runs/RUN_2023.07.03_06.39.20/logs/floorplan/5-tap.log)...
# [INFO]: Power planning with power {VDD} and ground {VSS}...
# [STEP 6]
# [INFO]: Generating PDN (log: runs/RUN_2023.07.03_06.39.20/logs/floorplan/6-pdn.log)...
# [WARNING]: DPL_CELL_PADDING is set higher than GPL_CELL_PADDING (2 > 0). This may result in inconsistent behavior.
# [STEP 7]
# [INFO]: Performing Random Global Placement (log: runs/RUN_2023.07.03_06.39.20/logs/placement/7-global.log)...
# [STEP 8]
# [INFO]: Running Placement Resizer Design Optimizations (log: runs/RUN_2023.07.03_06.39.20/logs/placement/8-resizer.log)...
# [STEP 9]
# [INFO]: Running Detailed Placement (log: runs/RUN_2023.07.03_06.39.20/logs/placement/9-detailed.log)...
# [STEP 10]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.07.03_06.39.20/logs/placement/10-dpl_sta.log)...
# [STEP 11]
# [INFO]: Running Clock Tree Synthesis (log: runs/RUN_2023.07.03_06.39.20/logs/cts/11-cts.log)...
# [STEP 12]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.07.03_06.39.20/logs/cts/12-cts_sta.log)...
# [STEP 13]
# [INFO]: Running Placement Resizer Timing Optimizations (log: runs/RUN_2023.07.03_06.39.20/logs/cts/13-resizer.log)...
# [STEP 14]
# [INFO]: Running Global Routing Resizer Design Optimizations (log: runs/RUN_2023.07.03_06.39.20/logs/routing/14-resizer_design.log)...
# [STEP 15]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.07.03_06.39.20/logs/routing/15-rsz_design_sta.log)...
# [STEP 16]
# [INFO]: Running Global Routing Resizer Timing Optimizations (log: runs/RUN_2023.07.03_06.39.20/logs/routing/16-resizer_timing.log)...
# [STEP 17]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.07.03_06.39.20/logs/routing/17-rsz_timing_sta.log)...
# [STEP 18]
# [INFO]: Running Global Routing (log: runs/RUN_2023.07.03_06.39.20/logs/routing/18-global.log)...
# [INFO]: Starting OpenROAD Antenna Repair Iterations...
# [STEP 19]
# [INFO]: Writing Verilog (log: runs/RUN_2023.07.03_06.39.20/logs/routing/18-global_write_netlist.log)...
# [STEP 20]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.07.03_06.39.20/logs/routing/20-grt_sta.log)...
# [STEP 21]
# [INFO]: Running Fill Insertion (log: runs/RUN_2023.07.03_06.39.20/logs/routing/21-fill.log)...
# [STEP 22]
# [INFO]: Running Detailed Routing (log: runs/RUN_2023.07.03_06.39.20/logs/routing/22-detailed.log)...
# [INFO]: No DRC violations after detailed routing.
# [STEP 23]
# [INFO]: Checking Wire Lengths (log: runs/RUN_2023.07.03_06.39.20/logs/routing/23-wire_lengths.log)...
# [STEP 24]
# [INFO]: Running SPEF Extraction at the nom process corner (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/24-parasitics_extraction.nom.log)...
# [STEP 25]
# [INFO]: Running Multi-Corner Static Timing Analysis at the nom process corner (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/25-rcx_mcsta.nom.log)...
# [STEP 26]
# [INFO]: Running Single-Corner Static Timing Analysis at the nom process corner (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/26-rcx_sta.log)...
# [STEP 27]
# [INFO]: Running Magic to generate various views...
# [INFO]: Streaming out GDSII with Magic (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/27-gdsii.log)...
# [INFO]: Generating MAGLEF views...
# [INFO]: Generating lef with Magic (/content/runs/RUN_2023.07.03_06.39.20/logs/signoff/27-lef.log)...
# [STEP 28]
# [INFO]: Running Magic Spice Export from LEF (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/28-spice.log)...
# [STEP 29]
# [INFO]: Writing Powered Verilog (logs: runs/RUN_2023.07.03_06.39.20/logs/signoff/29-write_powered_def.log, runs/RUN_2023.07.03_06.39.20/logs/signoff/29-write_powered_verilog.log)...
# [STEP 30]
# [INFO]: Writing Verilog (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/29-write_powered_verilog.log)...
# [STEP 31]
# [INFO]: Running LVS (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/31-lvs.lef.log)...
# [STEP 32]
# [INFO]: Running Magic DRC (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/32-drc.log)...
# [INFO]: Converting Magic DRC database to various tool-readable formats...
# [INFO]: No DRC violations after GDS streaming out.
# [STEP 33]
# [INFO]: Running OpenROAD Antenna Rule Checker (log: runs/RUN_2023.07.03_06.39.20/logs/signoff/33-antenna.log)...
# [INFO]: Saving current set of views in 'runs/RUN_2023.07.03_06.39.20/results/final'...
# [INFO]: Saving runtime environment...
# [INFO]: Generating final set of reports...
# [INFO]: Created manufacturability report at 'runs/RUN_2023.07.03_06.39.20/reports/manufacturability.rpt'.
# [INFO]: Created metrics report at 'runs/RUN_2023.07.03_06.39.20/reports/metrics.csv'.
# [INFO]: There are no max slew, max fanout or max capacitance violations in the design at the typical corner.
# [INFO]: There are no hold violations in the design at the typical corner.
# [INFO]: There are no setup violations in the design at the typical corner.
# [SUCCESS]: Flow complete.
# [INFO]: Note that the following warnings have been generated:
# [WARNING]: PDK 'gf180mcuC', SCL 'gf180mcu_fd_sc_mcu7t5v0' will generate errors with instantiated stdcells in the design.
# [WARNING]: Either disable QUIT_ON_LINTER_ERRORS or remove the instantiated cells.
# [WARNING]: DPL_CELL_PADDING is set higher than GPL_CELL_PADDING (2 > 0). This may result in inconsistent behavior.

# %% [markdown]
# ## Display layout

# %%
import pathlib
import gdstk
import IPython.display

gdss = sorted(pathlib.Path('runs').glob('*/results/final/gds/*.gds'))
library = gdstk.read_gds(gdss[-1])
top_cells = library.top_level()
top_cells[0].write_svg('inverter.svg')
IPython.display.SVG('inverter.svg')

# %% [markdown]
# ## Metrics
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/datapoint_definitions.html)

# %%
import pandas as pd
import pathlib

pd.options.display.max_rows = None
reports = sorted(pathlib.Path('runs').glob('*/reports/metrics.csv'))
df = pd.read_csv(reports[-1])
df.transpose()
# Out:
#                                                      0
# design                                        /content
# design_name                                   inverter
# config                         RUN_2023.07.03_06.39.20
# flow_status                             flow completed
# total_runtime                                0h2m9s0ms
# routed_runtime                              0h1m57s0ms
# (Cell/mm^2)/Core_Util                      3805.870174
# DIEAREA_mm^2                                  0.007883
# CellPer_mm^2                               1902.935087
# OpenDP_Util                                         -1
# Final_Util                                          -1
# Peak_Memory_Usage_MB                            427.05
# synth_cell_count                                     1
# tritonRoute_violations                               0
# Short_violations                                     0
# MetSpc_violations                                    0
# OffGrid_violations                                   0
# MinHole_violations                                   0
# Other_violations                                     0
# Magic_violations                                     0
# pin_antenna_violations                               0
# net_antenna_violations                               0
# lvs_total_errors                                     0
# cvc_total_errors                                    -1
# klayout_violations                                  -1
# wire_length                                         85
# vias                                                12
# wns                                                0.0
# pl_wns                                              -1
# optimized_wns                                       -1
# fastroute_wns                                       -1
# spef_wns                                           0.0
# tns                                                0.0
# pl_tns                                              -1
# optimized_tns                                       -1
# fastroute_tns                                       -1
# spef_tns                                           0.0
# HPWL                                                -1
# routing_layer1_pct                                 0.0
# routing_layer2_pct                                1.42
# routing_layer3_pct                                1.85
# routing_layer4_pct                                 0.0
# routing_layer5_pct                                 0.0
# routing_layer6_pct                                  -1
# wires_count                                          2
# wire_bits                                            2
# public_wires_count                                   2
# public_wire_bits                                     2
# memories_count                                       0
# memory_bits                                          0
# processes_count                                      0
# cells_pre_abc                                        1
# AND                                                  0
# DFF                                                  0
# NAND                                                 0
# NOR                                                  0
# OR                                                   0
# XOR                                                  0
# XNOR                                                 0
# MUX                                                  0
# inputs                                               1
# outputs                                              1
# level                                                1
# DecapCells                                          10
# WelltapCells                                         0
# DiodeCells                                           0
# FillCells                                            9
# NonPhysCells                                        15
# TotalCells                                          34
# CoreArea_um^2                                 487.3344
# power_slowest_internal_uW                           -1
# power_slowest_switching_uW                          -1
# power_slowest_leakage_uW                            -1
# power_typical_internal_uW                     0.000005
# power_typical_switching_uW                    0.000006
# power_typical_leakage_uW                           0.0
# power_fastest_internal_uW                           -1
# power_fastest_switching_uW                          -1
# power_fastest_leakage_uW                            -1
# critical_path_ns                                  1.07
# suggested_clock_period                            10.0
# suggested_clock_frequency                        100.0
# CLOCK_PERIOD                                      10.0
# FP_ASPECT_RATIO                                      1
# FP_CORE_UTIL                                        50
# FP_PDN_HPITCH                                       25
# FP_PDN_VPITCH                                       25
# GRT_ADJUSTMENT                                     0.3
# GRT_REPAIR_ANTENNAS                                  1
# PL_TARGET_DENSITY                                 0.75
# RUN_HEURISTIC_DIODE_INSERTION                        0
# STD_CELL_LIBRARY               gf180mcu_fd_sc_mcu7t5v0
# SYNTH_MAX_FANOUT                                    10
# SYNTH_STRATEGY                                  AREA 0
